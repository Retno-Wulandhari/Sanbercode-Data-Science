# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('Downloads/diamonds')
df
# Out:
#       carat      cut color clarity  depth  table  price     x     y     z
# 0      0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4      0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 7009   0.74    Ideal     F    VVS2   61.7   57.0   4157  5.79  5.84  3.59
# 7010   0.90    Ideal     I     VS2   62.0   53.0   4157  6.17  6.23  3.85
# 7011   1.10    Ideal     J     SI2   60.9   56.0   4157  6.68  6.72  4.08
# 7012   1.16  Premium     H     SI2   58.8   61.0   4157  6.93  6.84  4.05
# 7013   0.90  Premium     F     SI1   61.2   59.0   4158   NaN   NaN   NaN
#
# [7014 rows x 10 columns]

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"
#plt.xlim(0,5)
sns.scatterplot(x='carat', y='price', hue='clarity', size='depth', palette=palette, data=df)

plt.title("Scatterplot of Diamond Carat vs. Price with Cut as Hue")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.legend(title='Cut')
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
#code here
plt.figure(figsize=(12, 8))
#sns.catplot(x='clarity', y='price', kind='box', col='cut', data=df, hue="clarity")
sns.catplot(data=df, x="clarity", y="price", col="cut", kind="box", height=4, aspect=.9, hue='clarity')
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=17mSiL-qQtFB2D8rUYB0v7d6tOrOHDoh6)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df = df.sample(n=300, random_state=123)

#code here
    
sns.pairplot(df, hue='cut', vars=["carat", "depth", "table", "price"], diag_kind='kde', markers=["p", "o", "s", "D", "X"], corner=True);

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=12rStINwUNGpqZd1iIGaqzTIvw9irAkJ0)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
with sns.axes_style('white'):
     sns.jointplot(x="carat", y="price", data=df, kind='kde')

# %%
#code here
with sns.axes_style('white'):
     sns.jointplot(x="carat", y="price", data=df, kind='reg')

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=17MY9L4bUSxuCIRxDl7Ey34_RrfXjlcim)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1A5vQ66KLZ9sbJ_qDoAkuAF3Z213ricZW)
